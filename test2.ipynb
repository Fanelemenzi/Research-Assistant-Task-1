# %%
import pandas as pd

pd.read_csv("F:\Coding Projects\RSA\dataset2.csv")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\26878\AppData\Local\Temp\ipykernel_7460\298423247.py:3: SyntaxWarning: invalid escape sequence '\C'
#   pd.read_csv("F:\Coding Projects\RSA\dataset2.csv")
#       Year Currency  Value_Share  Count_Share
# 0   2009.0      EUR         1.84         0.49
# 1   2009.0    Other        37.54        76.56
# 2   2009.0      USD         5.85         4.22
# 3   2009.0      ZAR        54.78        18.74
# 4   2010.0      EUR         1.85         0.47
# 5   2010.0    Other        36.27        78.33
# 6   2010.0      USD         8.11         4.22
# 7   2010.0      ZAR        53.77        16.98
# 8   2011.0      EUR         2.29         0.68
# 9   2011.0    Other        17.73        74.53
# 10  2011.0      USD        12.08         4.61
# 11  2011.0      ZAR        67.90        20.18
# 12  2012.0      EUR         3.30         1.21
# 13  2012.0    Other         5.10        21.61
# ...

# %%
display(pd)
# Out:
# <module 'pandas' from 'c:\\Users\\26878\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
print(pd.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\Coding Projects\RSA\test2.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/Coding%20Projects/RSA/test2.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> print(pd.head())
#
# AttributeError: module 'pandas' has no attribute 'head'
